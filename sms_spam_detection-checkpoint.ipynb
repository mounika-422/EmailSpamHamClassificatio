# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("spam.csv",encoding='latin-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
#1.data cleaning
#2.EDA (Exploratory data analysis)
#3.text preprocessing
#4.model building
#5.evaluation
#6.Improvement
#7.deploy

# %%
##Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 3984  ham           Whatever, juliana. Do whatever you want.
# 951   ham                           Shb b ok lor... Thanx...
# 4260  ham                           Pls dont forget to study
# 3387  ham          Same as kallis dismissial in 2nd test:-).
# 4850  ham  Gain the rights of a wife.dont demand it.i am ...

# %%
#renaming the columns

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 3383   spam  FREE MSG:We billed your mobile number by mista...
# 2665    ham                     R u meeting da ge at nite tmr?
# 1252    ham  Yeah like if it goes like it did with my frien...
# 1571    ham                  Near kalainar tv office.thenampet
# 4824    ham         I am going to sleep. I am tired of travel.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()#encoding ham as 1 and spam as 0

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.sample(5)
# Out:
#       target                                               text
# 3979       1                                 ringtoneking 84484
# 3379       0                  Just finished. Missing you plenty
# 978        0  Hey you can pay. With salary de. Only  &lt;#&g...
# 2054       0      Y so late but i need to go n get da laptop...
# 2562       0               Yeah I am, so I'll leave maybe 7ish?

# %%
df.isnull().sum()#checking for null values
# Out:
# target    0
# text      0
# dtype: int64

# %%
#check for Duplicate values

# %%
df.duplicated().sum()
# Out:
# 403

# %%
#remove duplicates
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#2.EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x7f97d5454080>,
#   <matplotlib.patches.Wedge at 0x7f97d54547b8>],
#  [Text(-1.0144997251399075, 0.42519443516002464, 'ham'),
#   Text(1.014499764949479, -0.4251943401757036, 'spam')],
#  [Text(-0.5533634864399495, 0.23192423736001339, '87.37'),
#   Text(0.5533635081542612, -0.23192418555038377, '12.63')])

# %%
#Data is imbalenced

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/student/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters']=df['text'].apply(len)

# %%
df['num_characters']
# Out:
# 0       111
# 1        29
# 2       155
# 3        49
# 4        61
#        ...
# 5567    161
# 5568     37
# 5569     57
# 5570    125
# 5571     26
# Name: num_characters, Length: 5169, dtype: int64

# %%
df.head(5)
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df.describe()
# Out:
#             target  num_characters    num_words  num_sentences
# count  5169.000000     5169.000000  5169.000000    5169.000000
# mean      0.126330       78.977945    18.453279       1.947185
# std       0.332253       58.236293    13.324793       1.362406
# min       0.000000        2.000000     1.000000       1.000000
# 25%       0.000000       36.000000     9.000000       1.000000
# 50%       0.000000       60.000000    15.000000       1.000000
# 75%       0.000000      117.000000    26.000000       2.000000
# max       1.000000      910.000000   220.000000      28.000000

# %%
df[df['target']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.120903       1.799601
# std         56.358207    13.493725       1.278465
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
#spam
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.967841
# std         30.137753    7.008418       1.483201
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       8.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,8))
sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'],color='red')
# Out:
# <AxesSubplot:xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(20,8))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'],color='red')
# Out:
# <AxesSubplot:xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Data preprocessing
#lower case/upper case
#tokenizing
#removing special characters
#removing stop wors and punctuation
#stemming

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/student/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/student/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
import string
string.punctuation
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def transform_text(text):
    text=text.lower()
    text=text.split(" ")
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)

# %%
transform_text("'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'")
# Out:
# 'jurong avail bugi n great world la e cine got amor'

# %%
ps.stem('loving')
# Out:
# 'love'

# %%
ps.stem('affordable')
# Out:
# 'afford'

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong avail bugi n great world la e cine g...
# 1          8              2                                      ok joke wif u
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                        u dun say earli u c alreadi
# 4         15              1                   nah think goe live around though

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(12,10))
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))
plt.figure(figsize=(12,10))
plt.imshow(ham_wc)

# %%
df[df['target']==0]['transformed_text'].tolist()
# Out:
# ['go jurong avail bugi n great world la e cine got amor',
#  'ok joke wif u',
#  'u dun say earli u c alreadi',
#  'nah think goe live around though',
#  'even brother like speak treat like aid',
#  'per request mell minnaminungint nurungu set callertun press copi friend callertun',
#  'gonna home soon want talk stuff anymor cri enough',
#  'search right word thank promis wont take help grant fulfil wonder bless',
#  'date sunday',
#  'oh watch',
#  'eh u rememb 2 spell ye v naughti make v',
#  'fine thatåõ way u thatåõ way gota b',
#  'serious spell',
#  'go tri 2 month ha ha joke',
#  'pay first da stock',
#  'aft finish lunch go str ard 3 smth u finish ur lunch',
#  'alright way meet',
#  'forc eat realli hungri mark get know sick turn lol',
#  'lol alway',
#  'catch bu fri egg make eat left dinner feel love',
#  'back pack car let know room',
#  'vagu rememb feel lol',
#  'wait still sure sarcast x want live us',
#  'yeah got 2 v n fallen actin like spoilt child got caught till go badli',
#  'k tell anyth',
#  'fear faint housework quick cuppa',
#  'ok go home look time msg xuhui go learn 2nd may lesson 8am',
#  'let know done',
#  'see letter b car',
#  'anyth u',
#  'saturday text see decid anyth tri invit',
#  'pl go ahead want great abiola',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummi',
#  '',
#  'hope like man well',
#  'call',
#  'get hep b immunis',
#  'fair anyth go',
#  'yeah tyler could mayb ask around bit',
#  'u know stubborn even want go kept tell mark weak hospit weak',
#  'think first time saw',
#  'gram usual run like half eighth smarter though get almost whole second gram',
#  'k fyi x ride earli tomorrow morn crash place tonight',
#  'never realiz embarass thought like sinc best could alway seem happi sorri sorri sorri room',
#  'know mallika sherawat find',
#  'call later',
#  'tell reach',
#  'sehwag odi',
#  'gonna pick burger way even pain kill',
#  'ha ha ha good girl situat',
#  'part check iq',
#  'sorri roommat took ok come',
#  'ok lar doubl check wif da hair dresser alreadi said wun cut v said cut look',
#  'today dedic song u dedic send ur valuabl frnd first rpli',
#  'plane give month',
#  'wah lucki save',
#  'finish class',
#  'hi babe im home wanna xx',
#  '',
#  'u call',
#  'wait call',
#  'that gentleman treat digniti',
#  'like peopl shi',
#  'oper',
#  'still look much earn',
#  'call later',
#  'call',
#  'ok way home hi hi',
#  'place man',
#  'yup next',
#  'call sm',
#  'real u get need 2 ticket one jacket alreadi use',
#  'ye start send request make pain came back back doubl coin factori gotta cash',
#  'realli still tonight babe',
#  'ela come wen ur',
#  'yeah stand close catch',
#  'sorri ok meet anoth spent late afternoon casualti mean done stuff42moro includ time sheet',
#  'smile pleasur smile pain smile troubl pour like rain smile sum1 hurt u smile becoz someon still love see u',
#  'havent plan buy check alreadi lido got 530 show e u finish work',
#  'watch telugu abt',
#  'finish load loan pay',
#  'wk ok hol ye bit forgot hairdress appoint four need get home n shower caus prob',
#  'pleas text noth els',
#  'okay name ur price long wen pick u ave x am xx',
#  'still look car gone 4the drive test',
#  'mean guess gave boston men chang search locat someth cuz signin page still say',
#  'umma life vava umma love lot dear',
#  'thank lot wish thank make birthday truli',
#  'hit get cash',
#  'would ip address test consid comput minecraft server',
#  'grumpi old mom like better alway one play',
#  'dont guess',
#  'plural noun',
#  'go',
#  'ok wif co like 2 tri new scare u dun like co u said',
#  'ur openin sentenc fine juz tt eatin much n puttin anythin special',
#  'enter cabin pa happi boss felt askd 4 lunch invit went',
#  'ye must speak friday ratio tortilla',
#  'uncl inform pay school pl buy',
#  'new address malarki',
#  'go sao mu done 12',
#  'ìï predict wat time finish',
#  'good',
#  'sent money sent text bother dont involv impos anyth first place',
#  '',
#  'hey r hope u r well del r long time give call sum time lucyxx',
#  'much',
#  '',
#  'call',
#  'first answer',
#  'haf',
#  'call meet',
#  'check room befor activ',
#  'got lazi forgot saw pouch like v',
#  'text way',
#  'wait',
#  'swt get tire littl thing 4 lovabl littl thing occupi biggest part gud',
#  'know pl open',
#  'ye see ya dot',
#  'what staff name take class',
#  'call check life begin qatar pl pray',
#  'delet contact',
#  'sindu got job birla soft',
#  'wine flow',
#  'yup thk cine better co need 2 go 2 plaza',
#  'ur typic',
#  'everywher even sometim open come flow dream world without half chore time joy lot tv show guess like thing must like hail time becom',
#  'aaooooright',
#  'leav hous',
#  'get interview good think miss',
#  'keep safe need miss alreadi envi everyon real life',
#  'new car hous new job',
#  'love excit day spend make',
#  'place ur point e cultur modul',
#  'hi best way avoid missunderstd wit belov',
#  'great fanci bridg need see tomo',
#  'ye complet also utter',
#  'need axi bank account bank',
#  'thk sure got time hop go 4 free muz call u discuss',
#  'time come',
#  'bloodi cant believ forgot surnam mr ill give u spanish begin',
#  'gonna finish bath',
#  'let know got money carlo make call',
#  'u still go',
#  'turn friend stay whole show back til feel free go ahead smoke worth',
#  'text doesnt repli let know log',
#  'spoke maneesha like know satisfi repli toll free ye',
#  'lift hope offer especi end month approach hurt anyway gr8 weekend',
#  'lol u trust',
#  'gentleman treat digniti',
#  'guy',
#  'go noth',
#  'hello handsom find job lazi work toward get back net mummi boytoy miss',
#  'haha minut',
#  'got xma radio get',
#  'ju reach go bath si use net tell u finish',
#  'join leagu peopl dont keep mean great deal friend time even great person great',
#  'hi complet',
#  'stop howev suggest stay someon abl give or everi',
#  'hope settl new school wishin gr8 day',
#  'gud mrng dear hav nice day',
#  'u got person stori',
#  'hamster hey tmr meet 1pm orchard',
#  'hi kate hope see tomorrow bit bloodi txt back u xxx',
#  'found enc',
#  'sent buck',
#  'hello darlin ive finish colleg txt u finish u love kate xxx',
#  'account refil success inr keralacircl prepaid account balanc rs transact id kr',
#  'goodmorn sleep',
#  'u call alter 11',
#  'ìï say like dat dun buy ericsson oso cannot oredi',
#  'aight dat straight dogg',
#  'pleas give us connect today refund bill',
#  'shoot big load get',
#  'hope great reward',
#  'home alway chat',
#  '',
#  'noe',
#  'sound home',
#  'final match head toward draw',
#  'slept well past',
#  'easi got select mean',
#  'take exam march 3',
#  'yeah think use gt atm sure anyway help let sure',
#  'ok take ur',
#  'os call ubandu run without instal hard use os copi import file system give repair',
#  'u say cours noth happen say v romant ju bit thk e nite sceneri nice',
#  'would realli appreci call need someon talk',
#  'hey compani elama po',
#  'life strict bcoz teacher teach lesson conduct life first conduct exam teach happi',
#  'dear good morn',
#  'get gandhipuram walk cross cut right side street road turn first',
#  'dear go rubber place',
#  'sorri batteri yeah',
#  'tv alway avail work',
#  'print come upstair',
#  'ill littl closer like bu stop street',
#  'wil reach',
#  'new argument win lose dont argu ur friend kick alway',
#  'tomarrow final hear laptop case',
#  'pleassssssseeeee tel v avent done sportsx',
#  'shine meant sound',
#  'although told u dat baig face watch realli like e watch u gave co fr thanx 4 everyth dat done',
#  'u rememb old',
#  'said dont slipper',
#  'ask call ok',
#  'kalli wont bat 2nd',
#  'didnt work ok goodnight fix readi time wake dearli miss good night',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'wen ur lovabl bcum angri wid dnt take coz angri childish n true way show deep care n kettoda nice day',
#  '',
#  'up 3day ship compani take way usp take week get lag may bribe nipost get',
#  'lemm know readi',
#  'necessarili expect done get back though headin',
#  'mmm yummi babe nice jolt suzi',
#  'lover need',
#  'park next come today',
#  'yup',
#  'anyway go shop co si done dun disturb u',
#  'luton 0125698789 ring ur',
#  'dint come',
#  'wana plan trip sometm',
#  'sure still tri get hold',
#  'download',
#  'come sort narcot situat',
#  'night end anoth morn come special may smile like sunni ray leav worri blue blue',
#  'usf might well take 1 car',
#  'bf',
#  '',
#  'tell rob mack gf theater',
#  'see bit',
#  'sent type food',
#  'hand celebr full swing',
#  'got call',
#  'u miss someon',
#  'ask money far',
#  '',
#  'yeah think usual still pass last get ahold anybodi let know throw',
#  'might come tonight class let earli',
#  '',
#  'hi babi im cruisin girl friend r u give call hour home that alright fone fone love jenni xxx',
#  'life mean lot love love peopl world call call',
#  'mail updat look edukkukaye raksha good one real',
#  'hey told name gautham',
#  'haf u found feel stupid da v cam',
#  '4 got',
#  'much buzi',
#  'accident delet resend',
#  'unless situat go gurl would appropri',
#  'hurt teas make end life die plz keep one rose grave say stupid miss nice day bslvyl',
#  'cant pick phone right pl send messag',
#  'need coffe run believ time week alreadi',
#  'rememb last time got somebodi high first time diesel',
#  'shit realli shock cant imagin def night u think somewher could crash save',
#  'oh way food want go meal',
#  'womdarful actor',
#  'think',
#  'jo ask u wana meet',
#  'lol friendship hang thread caus u buy',
#  'garag bookshelf',
#  'today accept accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#  'say give call got money definit buy end week',
#  'hi way u normal real ur hope know u 4 rest hope u find wot',
#  'made great day',
#  'happi',
#  'guess go 4 kb n power dunno tahan power yoga thk got lo forgot',
#  'realli friend afraid',
#  'coffe',
#  'merri christma love ya',
#  'dont go watch x men haha',
#  'cud u tell ppl im gona b bit l8 co 2 buse hav gon past co full im still waitin 4 pete x',
#  'would could meet bristol road somewher get touch plan take good week',
#  '',
#  'hi today',
#  'say good sign know track record read women',
#  'text park',
#  'read text sent meant read light',
#  '',
#  'mayb could get book tomo return immedi',
#  'chanc might evapor soon violat privaci steal phone number cool pleas contact report',
#  'home still',
#  'come havent wine dine',
#  'surf',
#  'u call call hand',
#  'ok great thanx',
#  'take post come must 1000 text happi one wiv hello carolin end bless',
#  'u hide',
#  'interest like',
#  'sister clear two round birla soft',
#  'go',
#  'di ju saw ur case huim havent sent u di',
#  'one small prestig problem',
#  'check realli miss see great month',
#  'nah help never iphon',
#  'car hour half go apeshit',
#  'today sorri ever angri ever misbehav hurt plz plz slap urself ur basic good',
#  'yo guy ever figur much need jay tri figur much safe spend weed',
#  'ish minut 5 minut',
#  'thank say happi onam fine rememb met insur qatar insha ex tata aig join',
#  'work even sleep sinc unemploy alway sleep everi day',
#  'got st long keep post',
#  'ha ha cool cool chikku',
#  'oh ok',
#  'check statu right',
#  'busi tri finish new look forward final meet',
#  'good afternoon dawn day refresh happi breath air smile think love alway',
#  'well know z take care',
#  'wat',
#  'text readi',
#  'hello boytoy geeee miss alreadi woke wish bed cuddl love',
#  'spoil bed well',
#  'go bath msg next',
#  'cant keep talk peopl sure pay agre pl tell want realli buy much will pay',
#  'say happen',
#  'could seen recognis',
#  'well lot thing happen lindsay new year bar ptbo blue heron someth go',
#  'keep payasam rinu bring',
#  'taught ranjith sir call sm like becau he verifi prabu told today pa dont mistak',
#  'guess must know way bodi repair quit sure take first guid ovul noth said reason worri keep followin',
#  'yeah give coupl minut track wallet',
#  'hey leav big take',
#  'hey late meet',
#  'took mr owl 3 lick',
#  'custom place call',
#  'mm time dont like fun',
#  'yup lunch buffet u eat',
#  'huh fr',
#  'hey sat go intro pilat kickbox',
#  'morn',
#  'ye think offic lap room think that last didnt shut',
#  'pick bout time',
#  'perform award calcul everi two current one month',
#  'actual sleep still might u call text rock send u text wen',
#  'alway put busi put pictur ass one open peopl ever would think pictur room would hurt make feel',
#  'good even al salam happi grace got offer',
#  'want chang field quickli wanna get system administr network',
#  'dear talk',
#  'hair cream',
#  'none happen til get though',
#  'great loxahatche xma tree burn start hour',
#  'haha get use drive usf know lot stoner',
#  'well slightli disastr class pm fav hope day coffe wld good stay late time place',
#  'good fanci drink someth',
#  'headin toward busetop',
#  'text miss miss u lot that everyth miss sent via',
#  'come room point iron plan weekend',
#  'co want thing',
#  'go yan jiu skip ard go cine den go mrt blah blah',
#  'bring home wendi',
#  'whatsup dont u want sleep',
#  'alright new goal',
#  'head text meet',
#  'last week take live',
#  'siva hostel',
#  'send ur friend receiv someth ur speak attitud repli',
#  'guess',
#  '',
#  'pain urin thing',
#  '7 mind give lift co got car',
#  'wnt buy bmw car vri hv shortag sourc arng di prob',
#  'home watch tv',
#  'usual take fifteen fuck minut respond ye question',
#  'book ticket',
#  'avail like right around hillsborough th',
#  'messag sent askin shoul pay',
#  'ask g told stori like ten time alreadi',
#  'long applebe fuck take',
#  'hi hope u get hasnt 50 min late',
#  'like love',
#  'realli told kalli best cricket sachin tough get',
#  'suppos wake',
#  'saw tot din c found group',
#  'hey wereth monkeespeopl say howdi gorgeou',
#  'batteri come get gram',
#  'well kinda rememb wot',
#  'wont get concentr dear know mind everyth',
#  'lol made plan new',
#  '10 min later',
#  'hank',
#  'thank hope good day today',
#  'detail want',
#  'ok tell stay yeah tough optimist thing improv',
#  'si think ill go make oreo',
#  'look ami ure intellig woman like u know u donåõt like like donåõt',
#  'hope result consist intellig start ask practicum link keep ear open ttyl',
#  'call guess isnt miss need want love ya',
#  'go thru differ decis cope heal everyth',
#  'u phone gonna die stay',
#  'never day give even reason thank god',
#  'call later ok bye',
#  'ok way railway',
#  'great love give receiv doggi style fave enjoy make love time per night',
#  'put stuff road keep get slipperi',
#  'go ride',
#  'ju wait 4 e rain 2',
#  'mani tell',
#  'long sinc',
#  'meant money enter account bank remov flat someon transfer account dollar got bank differ charg also sure trust 9ja person send account detail',
#  'nice line said broken plz cum 1 time infront wise trust good',
#  'ok gonna head usf like fifteen minut',
#  'love u',
#  'tension',
#  'pick anoth 8th',
#  'guy get g said think stay mcr',
#  'almost see u sec',
#  'yo friend alreadi ask work',
#  'watch tv',
#  'thank cant wait tast real',
#  'chang fb jaykwon thuglyf falconerf',
#  'win realli 1 side long',
#  'dear reach happen',
#  'depend want type sent fade want ralph mayb 2',
#  'think fix send test',
#  'sorri man dri want could trade back half could buy shit credit card',
#  'meet call later',
#  'class',
#  'free call',
#  'got',
#  'think go sorri repli late',
#  'told accentur',
#  'kate jackson rec center',
#  'dear reach room',
#  'fight world u either win lose bt fightng some1 close u dificult u lose u lose u win u still',
#  'come',
#  'check',
#  'went fish',
#  'wait e car bore co wait outsid got noth 2 home stuff watch tv',
#  'mayb westshor hyde park place near',
#  'know bring school fee pay rent stuff like that need friend',
#  '',
#  'opinion jada kusruthi lovabl silent spl charact matur stylish simpl pl',
#  '8 still scroung ammo want give new ak tri',
#  'heart sori',
#  'lol ok forgiven',
#  'chang tat',
#  'competit',
#  'way transport less problemat sat u want ask n join feel need know definit no book',
#  'usual person unconsci children adult may behav call',
#  'ebay might less',
#  'shall come get pickl',
#  'gonna go get taco',
#  '',
#  'hi b ard 4 enjoy n merri',
#  'pretti ladi like',
#  'jay say',
#  '',
#  '',
#  'call hope l8r malaria know miss miss bani pl give love great',
#  'good goe day hope mayb got lead think boytoy send passion kiss across sea',
#  'probabl gonna see later tonight',
#  'mayb fat finger press button know',
#  'ummmmmaah mani mani happi return day dear sweet happi birthday dear',
#  'tirupur start offic call',
#  'famou quot develop abil listen uncondit without lose temper self mean',
#  'go colleg els ill come',
#  '4 oclock bash flat',
#  'girl stay girl need recoveri id rather pass fun coop bed',
#  'special',
#  'know need get hotel got invit cali sweet come english weddin',
#  'sorri took omw',
#  'wait',
#  'ok give 5 minut think see btw cut hair whole',
#  'imagin final get sink bath put mayb even eat left also imagin feel cage cock surround bath remind alway own cuck',
#  'hurri like three day',
#  'get acknowledg astoundingli tactless gener faggi demand blood oath fo',
#  'everi night take warm bath drink cup milk see work still need loos know',
#  'look fri pan case cheap book silli fri pan like book',
#  'well uv caus sunscreen like essenti theseday',
#  '',
#  'know friend alreadi told',
#  'hi thank',
#  'u alway c ex dunno abt first time u repli lucki workin got bao ur sugardad',
#  'hi msg',
#  'thanx 4 e browni v',
#  'geeeee love much bare stand',
#  'fuck babe miss know let send money toward net need want crave',
#  'ill call u 2mrw address icki american freek wont stop callin 2 bad jen k',
#  'oooh bed ridden think',
#  'go gym love hope ok good day babe miss much alreadi',
#  'love daddi make scream go slap ass',
#  'wot u wanna',
#  'yar lor wait 4 mum 2 finish sch lunch whole morn stay home clean room room quit',
#  'know lab goggl went',
#  'open',
#  'wait',
#  'nope wait sch 4',
#  'tire argu week want',
#  'ìï wait 4 sch finish ard',
#  'arngd marriag u r walkin unfortuntli snake bite bt love marriag danc frnt snake sayin bite bite',
#  'huh dinner outsid',
#  'ok anyway need chang said',
#  'abl want kid one',
#  'hope show jjc take live dream',
#  'tell u headach want use 1 hour sick',
#  'dun thk quit go jazz yogasana oso go meet em lesson',
#  'pleas ring meiv hardli gotani',
#  'ya srsli better yi tho',
#  'call later',
#  'still grand',
#  'met stranger choos long world friendship never let friend gud',
#  '',
#  'gud mrng dear nice day',
#  'exhaust train much wine sleep well',
#  'go buy present',
#  'mind tsunami occur rajnik stop swim indian',
#  'u send home first ok readi',
#  'speak cash',
#  'happi come noon',
#  'meet lunch',
#  'take care n get well soon',
#  'meant say cant wait see u get bore bridgwat banter',
#  'neva mind',
#  'imma get drink want come find',
#  'valentin send di msg ur 5 answer r someon realli love colour suit',
#  'mani depend',
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u',
#  'call said choos',
#  'valentin know earli hundr handsom beauti thought finish aunti uncl',
#  'like v shock co tell shuhui like tell leona like dat almost know got ask abt ur reaction',
#  'famili',
#  'come n pick come immedi aft ur',
#  'let let kind weather bring ppl togeth friendship',
#  'dear got dollar hi hi',
#  'good word may leav u dismay mani',
#  'make sure alex know birthday fifteen minut far concern',
#  'got thing may pub',
#  'nah bring bud drink someth actual littl use straight cash',
#  'haha good offici paid market 8th',
#  'mani lick take get center tootsi',
#  'yup thk r e teacher said make face look darren ask 2 cut',
#  'pleas dont say like hi hi hi',
#  'thank',
#  'oh forward thought send',
#  'got seventeen pound seven hundr ml hope',
#  'n',
#  'hope kind one load reason biola',
#  'login dat dad fetch home',
#  '',
#  'askd u question hour answer',
#  'well imma definit need restock let know',
#  'said sound gorgeou man kind person need smile brighten',
#  'probabl gonna swing wee bit',
#  'ya readi thursday',
#  'brave buse taken train mean jolli good rest week',
#  'watch listen music eve go templ',
#  'mind ask dont say',
#  'send',
#  'that sometim slow sonetim rough hard',
#  'gonna say would normal start panic sorri see',
#  'know wesley bet hella',
#  'fine miss',
#  'tell drug get impati',
#  'sun cant come earth send luv cloud cant come river send luv cant come meet send care msg gud evng',
#  'doesnt make sens take unless need know',
#  'lay 3',
#  'repent',
#  'sorri go home daddi come fetch',
#  'leav start prepar',
#  'ye studi posit kama sutra',
#  'en chikku nang bakra msg',
#  'minut still need buy',
#  'pay',
#  'good ttyl',
#  'u receiv',
#  'ho ho big belli see ya tomo',
#  'worri say anyth like said last whatev want',
#  'got way could pick',
#  'dont knw drink',
#  'say hi find got great escap',
#  'r u bet still go 4 lunch',
#  'caus freaki lol',
#  'miss call caus yell miss wait u come lone',
#  'place talk',
#  'ìï log 4 sdryb8i',
#  'xy go 4 e',
#  'want ask wait 4 finish co lect finish hour',
#  'finish work',
#  'everi king cri babi everi great build imprtant u r u wil reach gud ni8',
#  'case u r come cochin pl call bfore u shall also reach tell day u r engag an',
#  'thank torch',
#  'farm',
#  'sorri troubl u buy 4d dad 2 big 1 sat n',
#  'sister hope great say abiola',
#  'purchas stuff today mail po box',
#  'ah look like ill prob send laptop get fix cuz gpu problem',
#  'good like entrepreneur',
#  'close still around',
#  'meet corpor st outsid gap see mind',
#  'mum ask buy food',
#  'also dont msg repli',
#  'much r will',
#  'import prevent dehydr give enough fluid',
#  'that bit even suppos good sure',
#  'true sat pray even felt',
#  'think get away trek long famili sorri',
#  'wanna gym harri',
#  'quit late ard 12 anyway wun b',
#  'height aeronaut professor wer calld wer askd 2 sit aftr sat wer told dat plane ws made dey hurri bt 1 didnt made student',
#  'seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#  'save person dorm send account detail money sent',
#  'also know lunch menu know',
#  'stuff sell tell',
#  'book msg call work go get membership px3748',
#  'macha dont feel assum one even wonder plan life begin anytim',
#  'oh send address',
#  'best',
#  'wondar full',
#  'ya even cooki jelli',
#  'world run feel let call keep run u r also',
#  'got look daddi want eat night',
#  'co lar ba dao 1 pm u never ask go said u would ask fri said u ask',
#  'alright gotta chang order half8th',
#  'anyway jide studi visit',
#  'dunno u ask',
#  'spring come earli',
#  'lol feel bad use money take steak dinner',
#  'even u dont get troubl tel twice tel neglect msg dont c read dont repli',
#  'leav qatar tonit search went add ur prayer',
#  'one talk',
#  'thank look realli',
#  'wish',
#  'haha mayb u know da feel like someon gd u faster go find one gal group attach',
#  'ye glad made',
#  'well littl thing good time',
#  'got room put clock back til 8 shout everyon get realis anoth hour',
#  'may free gym',
#  'men like shorter gaze',
#  'dunno ju say go time',
#  'promis take good care run pleas send pic get',
#  'reason spoken anyway great week best exam',
#  'monday next give full gist',
#  'dont gimm lip caveboy',
#  'get librari',
#  'reali recognis number confus r u',
#  'didnt',
#  'cant think anyon spare room top head',
#  'faith make thing make thing make thing three',
#  'u made appoint',
#  'call vibrat act might hear text',
#  'oh u still felt shit morn think anoth night leav',
#  'noth ju tot u would ask co u ba went mt faber yest ju went alreadi mah today go ju call',
#  'wish famili merri ma happi new year',
#  'nt got somethin unless meetin 4 dinner wonder go ti',
#  'lol school alreadi close appar drive inch snow suppos',
#  'get anywher damn job hunt',
#  'u hair yeah still 4 wat',
#  'idc get weasel way shit twice row',
#  'wil got space',
#  'thank pick',
#  'go tell friend sure want live smoke much spend hour beg come smoke',
#  'kate love see tonight ill phone got sing guy gave',
#  'happi new year dear realli miss got number decid send text wish abiola',
#  'mean get door',
#  'hmmm thought said 2 hour 3 late punish',
#  '',
#  'dont think turn like randomlli within 5min open',
#  'suppos make still town though',
#  'time fix sometim get complet diff go figur',
#  'hope enjoy game sorri touch pl know fondli bein thot great abiola',
#  'e best 4 ur drive tmr',
#  'u sound like jan c thatåõ',
#  'omg want weigh lost',
#  'gener uncount noun u piec',
#  'realli get hang',
#  'boy wherear friendsar thekingshead come canlov',
#  'ok msg u b4 leav',
#  'minut',
#  'appt fault u told u twice',
#  'k',
#  'dled 3d imp',
#  'make sure know smokin yet',
#  'boooo alway',
#  'take half day leav bec well',
#  'ugh wanna get',
#  '',
#  'ring come guy gift futur hint hint',
#  'borrow ur bag',
#  'miss',
#  'lot use one model youi bring match',
#  'also bring galileo dobbi',
#  'respond',
#  'u enjoyin u seem 2 b gettin well ure care iåõllspeak 2u soonlot lovem',
#  'good afternoon crave ach fuck miss babe',
#  'road cant txt',
#  'hmm bit piec lol',
#  'brain dear',
#  'got',
#  'sorri light turn meant anoth friend want worth may around',
#  'thank yesterday hope enjoy mojibiola',
#  'hi mate rv u hav nice hol messag 3 say hello coz havenåõt sent u 1 age start drive stay',
#  'thank skype wit kz didnt get pleasur hope given ultimatum countin messag sent day ago',
#  'sure result',
#  'good morn great success',
#  'late pay rent past month pay felt would inconsider nag someth give great cost didnt speak howev recess wont abl pay charg month henc askin well ahead pleas thank',
#  'luv u soo much u donåõt understand special u r 2 ring u 2morrow luv u xxx',
#  'pl send comprehens mail',
#  'mother pass away last pray',
#  '',
#  'meanwhil shit xavier decid give us second warn samantha come play guitar impress also think doug realiz live anymor',
#  'stomach thru much trauma swear better lose',
#  'call',
#  'yeah bare enough room two x mani fuck sorri see later',
#  'u reach orchard u wan 2 go buy ticket',
#  'want bring inner',
#  'da run activ full version',
#  'poor urfeel bettersn probthat overdos work hey go care spk 2 u sn lot lovejen',
#  'stop told return say order',
#  'go take babe',
#  'hai ana tomarrow come ill sathi go rto repli came',
#  'spoon',
#  'say somebodi name tampa',
#  'work go',
#  'brother geniu',
#  'guess whenev get hold mayb hour text',
#  'u find time bu coz need sort stuff',
#  'dude ive see lotta corvett late',
#  'consid wall bunker shit import never play peac guess place high enough matter',
#  'well offici philosoph u wanna call home readi',
#  'go still need littl experi understand american custom',
#  'text drop x',
#  'ugh long want cuddl take nap',
#  'talk atleast otherwis miss best friend shesil',
#  'need see someth',
#  'knew give break time woul lead alway want miss gonna gibe midnight movi gonna get til need come need getsleep need b studdi ear',
#  'love give use lot babi fave',
#  'dude go sup',
#  'yoyyooo u know chang permiss drive usb flash drive',
#  'gibb hussey',
#  'like talk pa abl dont know',
#  'dun cut short u dun like quit',
#  'unbeliev faglord',
#  'knew time murder exactli',
#  'ask',
#  'great think',
#  'ie',
#  'ok noe busi realli bore msg oso dunno wat colour choos 4',
#  'g class earli tomorrow thu tri smoke',
#  'superb grate u dont everyth u mean u still opportun happier tomorrow u',
#  'hope good check',
#  'use hope agent drop sinc book thing whole nyc',
#  'thursday sure work',
#  'probabl money thing come due sever outstand invoic work two three month',
#  'possibl teach',
#  'wonder phone batteri went dead tell love babe',
#  'love smell bu',
#  'get worri derek taylor alreadi assum worst',
#  'hey charl sorri late',
#  'give plu said grinul greet whenev speak',
#  'white fudg oreo store',
#  'love come took long leav got word ym happi see sad miss',
#  'sorri hurt',
#  'feel eat sweet week caus today plan pig diet hungri',
#  'ok lor still project meet',
#  'call wait',
#  'could ask carlo could get anybodi els chip',
#  'actual send remind wonder weekend',
#  'peopl see think iam addict bcoz know iam addict sweet bslvyl',
#  'hey gave photo regist drive tmr wanna meet',
#  'dont talk ever ok',
#  'u wana see',
#  'way pl send number',
#  'shall avalarr hollalat',
#  'went attend anoth two round still reach',
#  'actual delet old blog',
#  'wait send aftr min',
#  'ate 1 mani slice pizza ugh alway',
#  'give kvb acc',
#  'oh come',
#  'realli sorri b abl 2 u find yr go',
#  'congratul ore mo owo enjoy wish mani happi moment fro wherev go',
#  'samu shoulder yet',
#  'time think need know near campu',
#  'dun wear jean',
#  'sinc',
#  '',
#  'made friday stuf like pig feel least writh pain kind',
#  'sell ton sell coin someon thru money back life',
#  'theyr lot hospit medic place',
#  'also sorta blown coupl time recent id rather text blue look weed',
#  'sent score sopha secondari applic think think research cost contact joke school one less expens one',
#  'cant wait see photo',
#  'hey book kb sat lesson go keep sat night free need meet confirm lodg',
#  'chk ur belovd ms dict',
#  'time want',
#  'lemm know whenev around',
#  'shb b ok',
#  'beauti truth read heart feel light someon feel heavi someon leav good',
#  'also rememb get bowl car',
#  'sorri c ur yar lor poor 4 one tmr brand new room 2 sleep',
#  'love could decid life would much less magic',
#  'welp appar retir',
#  'sort code acc bank repli confirm sent right',
#  '',
#  'u sure u take sick',
#  'yo chad gymnast class wanna site say christian class',
#  'better still catch let ask sell',
#  'sure night know noon menu',
#  'u want come beauti necklac token heart give wife one give call wait till',
#  'will go aptitud',
#  'wont b tri 2 sort hous',
#  'yar lor wan 2 go c hors race today eat earlier ate chicken',
#  'haha omw back',
#  'yup thk e shop close',
#  'account',
#  'eh u send wrongli',
#  'hey ad crap nite borin without ya 2 boggi u bore thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont know second time weak like keep notebook eat day anyth chang day sure noth',
#  'hey salari',
#  'anoth need chocol weed',
#  'start search get job great potenti',
#  'reckon need town eightish walk',
#  'look fuckin fuck think',
#  'yo guess drop',
#  'carlo say mu minut',
#  'offic call',
#  'geeee miss know think wait till next year togeth',
#  'yun ubi one say wan call 67441233 look got ubi tech 1st 5wkg',
#  'gotta drive back sd butt',
#  '26th juli',
#  'hi im relax time get 7am everi parti good get home tomorrow',
#  'ìï wan come come din c stripe',
#  'xma stori xma msg xma miracl hav bless month ahead wish u merri',
#  '',
#  'chang e one next',
#  'yetund class run water make pl',
#  'lot happen feel beth aunt charli work helen',
#  'wait 4 bu stop aft ur lect dun c go get car come back n pick',
#  'aight thank comin',
#  'heard abt',
#  'say syllabu',
#  'say anyth',
#  'give sec think think',
#  'quit know still get hold cud pick bout see',
#  '',
#  'dear leav qatar tonit apt keep touch',
#  'lol would mom would fit tell whole famili crazi terribl',
#  'got home still awak',
#  'dunno close oredi ìï v',
#  'buy meat lover u get',
#  'ask wat',
#  'cudnt pick frm ctla cochin mobil style',
#  'shall send exe mail',
#  'nope watch tv go v',
#  'check',
#  'good afternoon gloriou anniversari sweet j hope find happi think send teas kiss across sea coax imag fond souveni',
#  'still',
#  'may call later pl',
#  'pattern recent crap',
#  'sore scratch talk',
#  'ye plm ur offic',
#  'around still',
#  'lol forgot eh bring babe',
#  'find way',
#  'use foreign stamp good lectur',
#  'yup bath',
#  'happi new year man',
#  'oh mr wanna play boss give rais give',
#  'zoe hit 2 im fuck shitin il defo tri hardest 2 cum 2morow luv u million lekdog',
#  'hello get back set comput fill belli goe loverboy miss alreadi',
#  'blanket thx',
#  'naughti littl better flirt n rather love someon n gettin hurt n gud nyt',
#  'edison rightli fool ask question wise man know us speechless gm',
#  'talk that wont',
#  'today go colleg abl atten',
#  'holla later',
#  'mmm that better got roast iåõd b better drink good',
#  'come',
#  '1 chang sentenc want 2 concentr educ career im leav',
#  'walk hour 2 c doesnåõt show care wont u believ im',
#  'avail soire june',
#  'u noe wat time e place dat sell 4d',
#  'got anoth one hospit data analysi start sure thesi got finish',
#  'get realli impati belliger',
#  'hiya comin 2 bristol 1 st week le got rudi new yr eve u bak colleg work send ink 2',
#  'pleas call',
#  'u drive',
#  'ard 515 like',
#  'tell femal throw decid get',
#  'work technic support',
#  'might come kerala 2 prepar take leav finalis plan travel finish urgent',
#  'sure time tho sure get librari see good',
#  'bitch later',
#  'mum went 2',
#  'free call wait',
#  'meet u tel shall work tomorrow',
#  'ju finish',
#  'make sure car back tonight',
#  'lul im gettin juici gossip two nurs talk fat one think she',
#  'aight ill get fb coupl minut',
#  'ami parchi na kicchu kaaj kort iccha korch phone ta tul',
#  'download clear dvd',
#  'pretti sculptur',
#  'convey regard',
#  'watch surya movi 6 pm vijay movi pokkiri',
#  'tell happen dont behav like ok need say',
#  'u get pic msg',
#  'send someon els',
#  'wat make peopl dearer de happi dat u feel u meet de pain u feel u miss',
#  'love start feel need everi time around first thing come would start day end everi time everi breath life happen around life name would cri give happi take readi fight anyon love craziest thing proov anyon girl beauti ladi whole alway sing prais start make chicken curri end maki beauti get everi morn thank god day would like say tell',
#  'like needl though v r v r nt abl 2 evn v 4few bt v alwi stay gud',
#  'think spatula',
#  'never noth',
#  'goodmorn today late',
#  'pleas da call mistak side sorri pl da goto',
#  'r',
#  'well weather complex need car move tax great sad part miss',
#  'reach tire come tomorro',
#  'ryder',
#  'buy ovul test strip send wont get til like send postal',
#  'tri get throw cliff',
#  'ne thing good u wrking start uni',
#  'busi come point figur tomorrow',
#  'yeah go bore depress sittin waitin phone hope wind drop scari',
#  'black shirt n blue thk c',
#  'aiyah sorri watch tv watch forgot 2 check',
#  'hen go swing',
#  'good goe day woke earli onlin wait hmmm italian boy onlin see',
#  'someon smoke everi time smoke last two week call text want smoke',
#  'get headach tri figur u trust',
#  '',
#  'ok ill tell compani',
#  'think get 8th usf time',
#  'mean still think teju',
#  'good ok leav',
#  'kalli home home town',
#  'let make saturday monday per',
#  'time drive go evalu',
#  'go 4 lunch wif famili aft dat go str 2 orchard',
#  'cancel get money',
#  'ur today plan',
#  'good morn',
#  'aiyar sorri lor forgot 2 tell',
#  'tonight catch new number',
#  'height guy throw luv letter gal fall brother head who gay',
#  'check error',
#  'howz u r',
#  'u wake thanx 4 e tau sar piah quit',
#  'k need login anyth',
#  'lol busi',
#  'u',
#  'usual vijay film',
#  'good mine realli busi much tomorrow',
#  'way send stuff wonder',
#  'tot ur paper end long wat u copi ju got u happi still haf 2 studi',
#  'babe lost',
#  'help ask work tmr',
#  'get caught e mrt station',
#  'drop tank',
#  'said text one',
#  'ok go chang',
#  'u find sitter sick slept day',
#  'sorri accident left phone silent last night check til got',
#  'someth came last think wun sign hee',
#  'adult would learn real dont like peep use drug dont comment',
#  'veggi',
#  'yun school got offer 2000 plu',
#  'sure neighbor didnt pick',
#  'sent',
#  'im time make oreo truffl',
#  'haha yeah see sec',
#  'number sir',
#  'lol hot air',
#  'ok come soon come otherwis tomorrow',
#  'msg r time silent say think u right also make u think least 4 gd drm',
#  'probabl swing roommat finish girl',
#  'happi new year',
#  'ìï dun need pick ur',
#  'better told 5 girl',
#  'horribl u eat mac eat u forgot abt alreadi u take long 2 thk toot b4 b wat shall',
#  'say fantast anyth need bigger life lift lose 2 think would first person 2 die n v',
#  'nw came hme',
#  'outsid head toward hard rock run',
#  'day class',
#  'chennai',
#  'flippin shit',
#  'k give break cstore',
#  'much bad avoid like',
#  'got car back',
#  'annoy',
#  'today late',
#  'point hangin mr right makin u happi',
#  'come correct good look figur',
#  'case guess see campu lodg',
#  '',
#  'come home one last time wont trust',
#  'night worri shame miss girl night quizz popcorn',
#  'c',
#  'said mind say matter',
#  'al moan n e thin goe wrong de argument r himso hav',
#  'neft transact refer number credit beneficiari account',
#  'otherwis part time job',
#  'know call',
#  'also feel yesterday night wait til 2day night',
#  'thank tri tell sura',
#  'whole car appreci last dad map read semi argument apart thing go',
#  'need strong',
#  'also maaaan miss',
#  'bday real april',
#  'guessin gonna',
#  ...]

# %%
spam_corpus=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 8176

# %%
from collections import Counter

# %%
plt.figure(figsize=(15,8))
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# /home/student/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ham_corpus=[]
for msg in df[df['target']==0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 27382

# %%
plt.figure(figsize=(15,8))
sns.barplot(pd.DataFrame(Counter(ham_corpus).most_common(30))[0],pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# /home/student/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#MODEL BUILDING

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
#from sklearn.linear_model import LogisticRegression
#lr=LogisticRegression(solver='liblinear',penalty='l1')

# %%
#X=cv.fit_transform(df['transformed_text']).toarray()
X=tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score
 #from sklearn.linear_model import LogisticRegression
# lrc=LogisticRegression(solver='liblinear',penalty='l1')
# lrc.fit(X_train,y_train)
# y_pred3=lrc.predict(X_test)
# print(accuracy_score(y_test,y_pred3))
# print(precision_score(y_test,y_pred3))
# from sklearn.ensemble import RandomForestClassifier
# rfc=RandomForestClassifier(n_estimators=50,random_state=20)
# rfc.fit(X_train,y_train)
# y_pred3=gnb.predict(X_test)
# print(accuracy_score(y_test,y_pred3))
# print(confusion_matrix(y_test,y_pred3))
# print(precision_score(y_test,y_pred3))
# from sklearn.tree import DecisionTreeClassifier
# dtc=DecisionTreeClassifier(max_depth=5)
# dtc.fit(X_train,y_train)
# y_pred3=dtc.predict(X_test)
# print(accuracy_score(y_test,y_pred3))
# print(confusion_matrix(y_test,y_pred3))
# print(precision_score(y_test,y_pred3))

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))

# %%
bnb.fit(X_train,y_train)
y_pred3=bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9758220502901354
# [[894   2]
#  [ 23 115]]
# 0.9829059829059829

# %%
import pickle

# %%
pickle.dump(tfidf,open('vectorizer.pk1','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
